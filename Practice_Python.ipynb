# %%
import pandas as pd

# %%
df = pd.DataFrame({'Name':['Luffy','Chopper','Zoro','Sanji'], 'Marks':[15,89,33,32]})
df

# %%
#Using Mask
mask = df['Marks']>30

# %%
#using mask to filter rows
df.loc[mask]['Name']
# Out:
# 1    Chopper
# 2       Zoro
# 3      Sanji
# Name: Name, dtype: object

# %%
# !wget https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/716/original/sales_dataset.csv?1651727754
# Out:
# --2022-07-30 10:14:28--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/716/original/sales_dataset.csv?1651727754
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 13.226.251.62, 13.226.251.17, 13.226.251.107, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|13.226.251.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94850204 (90M) [text/plain]
# Saving to: ‘sales_dataset.csv?1651727754.1’
#
# sales_dataset.csv?1 100%[===================>]  90.46M   121MB/s    in 0.7s
#
# 2022-07-30 10:14:28 (121 MB/s) - ‘sales_dataset.csv?1651727754.1’ saved [94850204/94850204]

# %%
df = pd.read_csv("/content/sales_dataset.csv?1651727754")
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df1 = df.groupby('Country')['StockCode'].unique()

# %%
len(df1['United Kingdom'])
# Out:
# 5303

# %%
df1.sort_values('Quantity', ascending = False)
# Out:
#                                     Quantity     Price  Customer ID
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545    298.18   14628933.0
# WHITE HANGING HEART T-LIGHT HOLDER     93050  18488.35   82666326.0
# ASSORTED COLOUR BIRD ORNAMENT          81306   5483.78   42672530.0
# JUMBO BAG RED RETROSPOT                78090   8230.47   42448849.0
# BROCADE RING PURSE                     70700    317.63    6362283.0
# ...                                      ...       ...          ...
# Unsaleable, destroyed.                -15644      0.00          0.0
# missing                               -16467      0.00          0.0
# printing smudges/thrown away          -19200      0.00          0.0
# given away                            -20000      0.00          0.0
# ?                                     -26757      0.00          0.0
#
# [5698 rows x 3 columns]

# %%
df1 = df.loc[df['Quantity']>0]

# %%
df1.sort_values('Price', ascending = False)
# Out:
#         Invoice  StockCode      Description  Quantity          InvoiceDate  \
# 241827   512771          M           Manual         1  2010-06-17 16:53:00
# 517955   537632  AMAZONFEE       AMAZON FEE         1  2010-12-07 15:08:00
# 540478   537632  AMAZONFEE       AMAZON FEE         1  2010-12-07 15:08:00
# 825443  A563185          B  Adjust bad debt         1  2011-08-12 14:50:00
# 135013   502263          M           Manual         1  2010-03-23 15:22:00
# ...         ...        ...              ...       ...                  ...
# 825445  A563187          B  Adjust bad debt         1  2011-08-12 14:52:00
# 825444  A563186          B  Adjust bad debt         1  2011-08-12 14:51:00
# 403472  A528059          B  Adjust bad debt         1  2010-10-20 12:04:00
# 276274  A516228          B  Adjust bad debt         1  2010-07-19 11:24:00
# 179403  A506401          B  Adjust bad debt         1  2010-04-29 13:36:00
#
#            Price  Customer ID         Country
# ...
