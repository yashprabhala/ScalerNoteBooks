# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 79.6MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 67.8MB/s]

# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("/content/movies.csv")
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue  \
# 0              0  43597  237000000         150  2787965087
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movies.drop("Unnamed: 0", axis =1,inplace = True)

# %%
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors = pd.read_csv("/content/directors.csv", index_col  = 0)
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
merge = pd.merge(movies,directors)
print(merge)
# Out:
# Empty DataFrame
# Columns: [id, budget, popularity, revenue, title, vote_average, vote_count, director_id, year, month, day, director_name, gender]
# Index: []

# %%
movies.shape
# Out:
# (1465, 11)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 126.0+ KB

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2349 entries, 0 to 2348
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  2349 non-null   object
#  1   id             2349 non-null   int64
#  2   gender         1724 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 73.4+ KB

# %%
#before proceeding further we want to know if all the directors id's in dircetors table is present in movies list or not. 
#we will get know if any missing values are Present

# %%
np.all(movies["director_id"].isin(directors["id"]))
# Out:
# True

# %%
data = movies.merge(directors, left_on =  "director_id", right_on = "id", how = "left")

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
import pandas as pd

df = pd.DataFrame({'name':["Mark","Ram","Dev","Clark"], "profession":['dev','mle','mle','sde'],"gender":['female','male','female','male'], "age":[21,20,30,25],"review":['need improvement','Can be improved','Scope of improvement','Can be improved'],"rating":[10,5,7,10]})
df
# Out:
#     name profession  gender  age                review  rating
# 0   Mark        dev  female   21      need improvement      10
# 1    Ram        mle    male   20       Can be improved       5
# 2    Dev        mle  female   30  Scope of improvement       7
# 3  Clark        sde    male   25       Can be improved      10

# %%
age_filter = df['name'][(df['age'] >= 23) & (df['age'] <=30)& (df['gender'] == "male")]

# %%
age_filter = age_filter.reset_index(drop=True)
age_filter
# Out:
# 0    Clark
# Name: name, dtype: object

# %%
data1 = pd.DataFrame({'name':["Ram","Shyam","Mukesh","Suresh"],'age':[10,18,60,50]})
data1
# Out:
#      name  age
# 0     Ram   10
# 1   Shyam   18
# 2  Mukesh   60
# 3  Suresh   50

# %%
data1.loc[data1['age'] <18, "age"] = "kid"
data1.loc[data1['age'] >= 18, "age"] = "adult"
data1.loc[data1['age'] <50, "age"] = "adult"
data1.loc[data1['age'] >=50, "age"] = "senior"

data1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-0b8f2470a1c8> in <module>()
#       1 data1.loc[data1['age'] <18, "age"] = "kid"
# ----> 2 data1.loc[data1['age'] >= 18, "age"] = "adult"
#       3 data1.loc[data1['age'] <50, "age"] = "adult"
#       4 data1.loc[data1['age'] >=50, "age"] = "senior"
#       5
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py in __ge__(self, other)
#      50     @unpack_zerodim_and_defer("__ge__")
#      51     def __ge__(self, other):
# ---> 52         return self._cmp_method(other, operator.ge)
#      53
# ...

# %%
df1 = pd.DataFrame({'A': [1,2,3,4], 'B':[11,22,33,44],'C':[11,22,33,44]}, index = ['first','second','third','fourth'])
    
df2 = pd.DataFrame({'D': ['a','b','c','d'], 'E': ['aa','bb','cc','dd'], 'F':['aaa','bbb','ccc','ddd']}, index = ['fourth','fifth','sixth','seventh'])

# %%
df1
# Out:
#         A   B   C
# first   1  11  11
# second  2  22  22
# third   3  33  33
# fourth  4  44  44

# %%
df2
# Out:
#          D   E    F
# fourth   a  aa  aaa
# fifth    b  bb  bbb
# sixth    c  cc  ccc
# seventh  d  dd  ddd

# %%
df3 = pd.concat([df1,df2])
df3
# Out:
#            A     B     C    D    E    F
# first    1.0  11.0  11.0  NaN  NaN  NaN
# second   2.0  22.0  22.0  NaN  NaN  NaN
# third    3.0  33.0  33.0  NaN  NaN  NaN
# fourth   4.0  44.0  44.0  NaN  NaN  NaN
# fourth   NaN   NaN   NaN    a   aa  aaa
# fifth    NaN   NaN   NaN    b   bb  bbb
# sixth    NaN   NaN   NaN    c   cc  ccc
# seventh  NaN   NaN   NaN    d   dd  ddd

# %%
df4=df3.drop(["fourth"])
df4
# Out:
#            A     B     C    D    E    F
# first    1.0  11.0  11.0  NaN  NaN  NaN
# second   2.0  22.0  22.0  NaN  NaN  NaN
# third    3.0  33.0  33.0  NaN  NaN  NaN
# fifth    NaN   NaN   NaN    b   bb  bbb
# sixth    NaN   NaN   NaN    c   cc  ccc
# seventh  NaN   NaN   NaN    d   dd  ddd

# %%
df3.loc['fourth','A']*2
# Out:
# fourth    8.0
# fourth    NaN
# Name: A, dtype: float64

# %%
df4 = df3.reset_index().drop_duplicates(subset='index', keep='last')          
df4 = df4.set_index('index').sort_index()
df4
# Out:
#            A     B     C    D    E    F
# index
# fifth    NaN   NaN   NaN    b   bb  bbb
# first    1.0  11.0  11.0  NaN  NaN  NaN
# fourth   NaN   NaN   NaN    a   aa  aaa
# second   2.0  22.0  22.0  NaN  NaN  NaN
# seventh  NaN   NaN   NaN    d   dd  ddd
# sixth    NaN   NaN   NaN    c   cc  ccc
# third    3.0  33.0  33.0  NaN  NaN  NaN

# %%
import pandas as pd

df = pd.DataFrame({'name':["Mark","Ram","Dev","Clark"], "profession":['dev','mle','mle','sde'],"gender":['female','male','female','male'], "age":[21,20,30,25],"review":['need improvement','Can be improved','Scope of improvement','Can be improved'],"rating":[10,5,7,10]})
df
# Out:
#     name profession  gender  age                review  rating
# 0   Mark        dev  female   21      need improvement      10
# 1    Ram        mle    male   20       Can be improved       5
# 2    Dev        mle  female   30  Scope of improvement       7
# 3  Clark        sde    male   25       Can be improved      10

# %%
df5 = df[['profession','gender','age']] [(df['rating'] >= 6)]
df5
# Out:
#   profession  gender  age
# 0        dev  female   21
# 2        mle  female   30
# 3        sde    male   25

# %%
a = pd.DataFrame({'name':["Ram","Shyam","Mukesh","Suresh"],'age':[10,18,60,50]})
a
# Out:
#      name  age
# 0     Ram   10
# 1   Shyam   18
# 2  Mukesh   60
# 3  Suresh   50

# %%
a['age']
# Out:
# 0    10
# 1    18
# 2    60
# 3    50
# Name: age, dtype: int64

# %%
a['age'] = a['age'].apply(lambda x: "kid" if x < 18 else ("senior" if x>50 else "adult"), axis =1 , result_type = "broadcast")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-9a13d930fdcb> in <module>()
# ----> 1 a['age'] = a['age'].apply(lambda x: "kid" if x < 18 else ("senior" if x>50 else "adult"), axis =1 , result_type = "broadcast")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
# ...

# %%
a
# Out:
#      name     age
# 0     Ram     kid
# 1   Shyam   adult
# 2  Mukesh  senior
# 3  Suresh   adult

# %%
df1 = pd.DataFrame({'Name': ['Chinnu','sai',"yash","akhil"], 'Age':[11,22,33,44],'Percentage':[75,80,33,44], 'Stream' : ['Commerce','Arts',"Dev","Dev"] })

# %%
df1
# Out:
#      Name  Age  Percentage    Stream
# 0  Chinnu   11          75  Commerce
# 1     sai   22          80      Arts
# 2    yash   33          33       Dev
# 3   akhil   44          44       Dev

# %%
df_new = df1['Name'] [(df1['Percentage']>=75) & ((df1["Stream"] == "Commerce") | (df1["Stream"] == "Arts"))]

# %%
df_new
# Out:
# 0    Chinnu
# 1       sai
# Name: Name, dtype: object

# %%
import pandas as pd
users = pd.DataFrame({"Roll_ID":[412,0,456,0,434,429,418],"Name":["John","Mitra","Ritz",0,"Anny","Hema","0"],"Marks":[0,32,25,0,35,28,38]})
users
# Out:
#    Roll_ID   Name  Marks
# 0      412   John      0
# 1        0  Mitra     32
# 2      456   Ritz     25
# 3        0      0      0
# 4      434   Anny     35
# 5      429   Hema     28
# 6      418      0     38

# %%
users.dropna(how = 'all')
# Out:
#    Roll_ID   Name  Marks
# 0      412   John      0
# 1        0  Mitra     32
# 2      456   Ritz     25
# 3        0      0      0
# 4      434   Anny     35
# 5      429   Hema     28
# 6      418      0     38
